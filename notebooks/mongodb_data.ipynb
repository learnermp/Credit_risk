# %% [markdown]
# # pymongo operations

# %% [markdown]
# ### sending records, receiving records, renaming categorical values in categorical columns

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\mriyu\\OneDrive\\Desktop\\DS2026\\MLOPs March 2026_Alexey\\06_Decision tree\\Credit_risk\\notebooks'

# %%
os.listdir()
# Out:
# ['credit_risk.ipynb', 'mongodb_demo.ipynb', 'monodb_data.ipynb']

# %%
import pandas as pd

# %%
# Exploring and basic cleaning of data
df = pd.read_csv(r"../data/CreditScoring.csv")

# %%
df.head()
# Out:
#    Status  Seniority  Home  Time  Age  Marital  Records  Job  Expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    Income  Assets  Debt  Amount  Price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.columns
# Out:
# Index(['Status', 'Seniority', 'Home', 'Time', 'Age', 'Marital', 'Records',
#        'Job', 'Expenses', 'Income', 'Assets', 'Debt', 'Amount', 'Price'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()

# %%
df.head(5)
# Out:
#    status  seniority  home  time  age  marital  records  job  expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
'''
 status: whether the customer managed to pay back the loan (1) or not (2)
 seniority: job experience in years
 home: type of homeownership: renting (1), a homeowner (2), and others
 time: period planned for the loan (in months)
 age: age of the client
 marital [status]: single (1), married (2), and others
 records: whether the client has any previous records: no (1), yes (2)
 job: type of job: full-time (1), part-time (2), and others
 expenses: how much the client spends per month
 income: how much the client earns per month
 assets: total worth of all the assets of the client
 debt: amount of credit debt
 amount: requested amount of the loan
 price: price of an item the client wants to buy
'''
# Out:
# '\n\uf0a1 status: whether the customer managed to pay back the loan (1) or not (2)\n\uf0a1 seniority: job experience in years\n\uf0a1 home: type of homeownership: renting (1), a homeowner (2), and others\n\uf0a1 time: period planned for the loan (in months)\n\uf0a1 age: age of the client\n\uf0a1 marital [status]: single (1), married (2), and others\n\uf0a1 records: whether the client has any previous records: no (1), yes (2) (It’s not\nclear from the dataset description what kind of records we have in this column.\nFor the purposes of this project, we may assume that it’s about records in the\nbank’s database.)\n\uf0a1 job: type of job: full-time (1), part-time (2), and others\n\uf0a1 expenses: how much the client spends per month\n\uf0a1 income: how much the client earns per month\n\uf0a1 assets: total worth of all the assets of the client\n\uf0a1 debt: amount of credit debt\n\uf0a1 amount: requested amount of the loan\n\uf0a1 price: price of an item the client wants to buy\n'

# %%
df.columns
# Out:
# Index(['status', 'seniority', 'home', 'time', 'age', 'marital', 'records',
#        'job', 'expenses', 'income', 'assets', 'debt', 'amount', 'price'],
#       dtype='object')

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'status': 1,
#   'seniority': 9,
#   'home': 1,
#   'time': 60,
#   'age': 30,
#   'marital': 2,
#   'records': 1,
#   'job': 3,
#   'expenses': 73,
#   'income': 129,
#   'assets': 0,
#   'debt': 0,
#   'amount': 800,
#   'price': 846},
#  {'status': 1,
#   'seniority': 17,
#   'home': 1,
#   'time': 60,
#   'age': 58,
#   'marital': 3,
#   'records': 1,
#   'job': 1,
#   'expenses': 48,
#   'income': 131,
#   'assets': 0,
#   'debt': 0,
#   'amount': 1000,
#   'price': 1658},
#  {'status': 2,
#   'seniority': 10,
#   'home': 2,
#   'time': 36,
#   'age': 46,
#   'marital': 2,
#   'records': 2,
#   'job': 3,
#   'expenses': 90,
#   'income': 200,
#   'assets': 3000,
#   'debt': 0,
#   'amount': 2000,
#   'price': 2985},
#  {'status': 1,
#   'seniority': 0,
#   'home': 1,
#   'time': 60,
#   'age': 24,
#   'marital': 1,
#   'records': 1,
#   'job': 1,
#   'expenses': 63,
#   'income': 182,
#   'assets': 2500,
#   'debt': 0,
#   'amount': 900,
#   'price': 1325},
#  {'status': 1,
# ...

# %%
import pymongo

'''
Cluster
   ↓
Database
   ↓
Collection
   ↓
Document
'''

# Variables required for storing data on MongoDB
DB_NAME = "Credit_Scoring_Database"
COLLECTION_NAME = "credit_scoring_data"
CONNECTION_URL = ""

# %%
# Posting data at MongoDb

client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)

# %%
# Faetching records from MongoDB and analyzing/processing the recodrs 
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i}: {j}")
# Out:
# 0: {'_id': ObjectId('69bbae32b0c8809709d7435a'), 'status': 1, 'seniority': 9, 'home': 1, 'time': 60, 'age': 30, 'marital': 2, 'records': 1, 'job': 3, 'expenses': 73, 'income': 129, 'assets': 0, 'debt': 0, 'amount': 800, 'price': 846}
# 1: {'_id': ObjectId('69bbae32b0c8809709d7435b'), 'status': 1, 'seniority': 17, 'home': 1, 'time': 60, 'age': 58, 'marital': 3, 'records': 1, 'job': 1, 'expenses': 48, 'income': 131, 'assets': 0, 'debt': 0, 'amount': 1000, 'price': 1658}
# 2: {'_id': ObjectId('69bbae32b0c8809709d7435c'), 'status': 2, 'seniority': 10, 'home': 2, 'time': 36, 'age': 46, 'marital': 2, 'records': 2, 'job': 3, 'expenses': 90, 'income': 200, 'assets': 3000, 'debt': 0, 'amount': 2000, 'price': 2985}
# 3: {'_id': ObjectId('69bbae32b0c8809709d7435d'), 'status': 1, 'seniority': 0, 'home': 1, 'time': 60, 'age': 24, 'marital': 1, 'records': 1, 'job': 1, 'expenses': 63, 'income': 182, 'assets': 2500, 'debt': 0, 'amount': 900, 'price': 1325}
# ...

# %%
collection.find()

# %%
list(collection.find())
# Out:
# [{'_id': ObjectId('69bbae32b0c8809709d7435a'),
#   'status': 1,
#   'seniority': 9,
#   'home': 1,
#   'time': 60,
#   'age': 30,
#   'marital': 2,
#   'records': 1,
#   'job': 3,
#   'expenses': 73,
#   'income': 129,
#   'assets': 0,
#   'debt': 0,
#   'amount': 800,
#   'price': 846},
#  {'_id': ObjectId('69bbae32b0c8809709d7435b'),
#   'status': 1,
#   'seniority': 17,
#   'home': 1,
#   'time': 60,
#   'age': 58,
#   'marital': 3,
#   'records': 1,
#   'job': 1,
#   'expenses': 48,
#   'income': 131,
#   'assets': 0,
#   'debt': 0,
#   'amount': 1000,
#   'price': 1658},
#  {'_id': ObjectId('69bbae32b0c8809709d7435c'),
#   'status': 2,
#   'seniority': 10,
#   'home': 2,
#   'time': 36,
#   'age': 46,
#   'marital': 2,
#   'records': 2,
#   'job': 3,
#   'expenses': 90,
#   'income': 200,
#   'assets': 3000,
#   'debt': 0,
#   'amount': 2000,
#   'price': 2985},
#  {'_id': ObjectId('69bbae32b0c8809709d7435d'),
#   'status': 1,
#   'seniority': 0,
#   'home': 1,
#   'time': 60,
# ...

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# Out:
#                         _id  status  seniority  home  time  age  marital  \
# 0  69bbae32b0c8809709d7435a       1          9     1    60   30        2
# 1  69bbae32b0c8809709d7435b       1         17     1    60   58        3
# 2  69bbae32b0c8809709d7435c       2         10     2    36   46        2
# 3  69bbae32b0c8809709d7435d       1          0     1    60   24        1
# 4  69bbae32b0c8809709d7435e       1          0     1    36   26        1
#
#    records  job  expenses  income  assets  debt  amount  price
# 0        1    3        73     129       0     0     800    846
# 1        1    1        48     131       0     0    1000   1658
# 2        2    3        90     200    3000     0    2000   2985
# 3        1    1        63     182    2500     0     900   1325
# 4        1    1        46     107       0     0     310    910

# %%
df.columns
# Out:
# Index(['_id', 'status', 'seniority', 'home', 'time', 'age', 'marital',
#        'records', 'job', 'expenses', 'income', 'assets', 'debt', 'amount',
#        'price'],
#       dtype='object')

# %%
if "_id" in df.columns:
    df = df.drop(columns=["_id"])

# %%
df.head()
# Out:
#    status  seniority  home  time  age  marital  records  job  expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.status.value_counts()
# Out:
# status
# 1    3200
# 2    1254
# 0       1
# Name: count, dtype: int64

# %%
status_values = {
1: 'ok',
2: 'default',
0: 'unknown'
}

df.status = df.status.replace(status_values)

'''
"replace" is used for Production-ready code:
Only replaces matching values
Leaves already mapped values unchanged
Safe to run multiple times
'''
df.head()
# Out:
#     status  seniority  home  time  age  marital  records  job  expenses  \
# 0       ok          9     1    60   30        2        1    3        73
# 1       ok         17     1    60   58        3        1    1        48
# 2  default         10     2    36   46        2        2    3        90
# 3       ok          0     1    60   24        1        1    1        63
# 4       ok          0     1    36   26        1        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.status.value_counts()
# Out:
# status
# ok         3200
# default    1254
# unknown       1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     status  seniority  home  time  age  marital  records  job  expenses  \
# 0       ok          9     1    60   30        2        1    3        73
# 1       ok         17     1    60   58        3        1    1        48
# 2  default         10     2    36   46        2        2    3        90
# 3       ok          0     1    60   24        1        1    1        63
# 4       ok          0     1    36   26        1        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.home.value_counts()
# Out:
# home
# 2    2107
# 1     973
# 5     783
# 6     319
# 3     247
# 4      20
# 0       6
# Name: count, dtype: int64

# %%
home_values = {
1: 'rent',
2: 'owner',
3: 'private',
4: 'ignore',
5: 'parents',
6: 'other',
0: 'unknown'
}

# %%
df.home = df.home.replace(home_values)

# %%
df.head()
# Out:
#     status  seniority   home  time  age  marital  records  job  expenses  \
# 0       ok          9   rent    60   30        2        1    3        73
# 1       ok         17   rent    60   58        3        1    1        48
# 2  default         10  owner    36   46        2        2    3        90
# 3       ok          0   rent    60   24        1        1    1        63
# 4       ok          0   rent    36   26        1        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.marital.value_counts()
# Out:
# marital
# 2    3241
# 1     978
# 4     130
# 3      67
# 5      38
# 0       1
# Name: count, dtype: int64

# %%
marital_values = {
1: 'single',
2: 'married',
3: 'widow',
4: 'separated',
5: 'divorced',
0: 'unk'
}

# %%
df.marital = df.marital.replace(marital_values)

# %%
df.head()
# Out:
#     status  seniority   home  time  age  marital  records  job  expenses  \
# 0       ok          9   rent    60   30  married        1    3        73
# 1       ok         17   rent    60   58    widow        1    1        48
# 2  default         10  owner    36   46  married        2    3        90
# 3       ok          0   rent    60   24   single        1    1        63
# 4       ok          0   rent    36   26   single        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.marital = df.marital.replace({'unk': 'unknown'})

# %%
df.head()
# Out:
#     status  seniority   home  time  age  marital  records  job  expenses  \
# 0       ok          9   rent    60   30  married        1    3        73
# 1       ok         17   rent    60   58    widow        1    1        48
# 2  default         10  owner    36   46  married        2    3        90
# 3       ok          0   rent    60   24   single        1    1        63
# 4       ok          0   rent    36   26   single        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.marital.value_counts()
# Out:
# marital
# married      3241
# single        978
# separated     130
# widow          67
# divorced       38
# unknown         1
# Name: count, dtype: int64

# %%
records_values = {
1: 'no',
2: 'yes',
0: 'unknown'
}

# %%
df.records = df.records.replace(records_values)

# %%
df.head()
# Out:
#     status  seniority   home  time  age  marital records  job  expenses  \
# 0       ok          9   rent    60   30  married      no    3        73
# 1       ok         17   rent    60   58    widow      no    1        48
# 2  default         10  owner    36   46  married     yes    3        90
# 3       ok          0   rent    60   24   single      no    1        63
# 4       ok          0   rent    36   26   single      no    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
job_values = {
1: 'fixed',
2: 'parttime',
3: 'freelance',
4: 'others',
0: 'unknown'
}

df.job = df.job.replace(job_values)

# %%
df.head()
# Out:
#     status  seniority   home  time  age  marital records        job  expenses  \
# 0       ok          9   rent    60   30  married      no  freelance        73
# 1       ok         17   rent    60   58    widow      no      fixed        48
# 2  default         10  owner    36   46  married     yes  freelance        90
# 3       ok          0   rent    60   24   single      no      fixed        63
# 4       ok          0   rent    36   26   single      no      fixed        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.debt.value_counts()
# Out:
# debt
# 0        3670
# 2000       59
# 1500       51
# 3000       46
# 1000       39
#          ...
# 130         1
# 290         1
# 2432        1
# 2040        1
# 23500       1
# Name: count, Length: 183, dtype: int64

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'status': 'ok',
#   'seniority': 9,
#   'home': 'rent',
#   'time': 60,
#   'age': 30,
#   'marital': 'married',
#   'records': 'no',
#   'job': 'freelance',
#   'expenses': 73,
#   'income': 129,
#   'assets': 0,
#   'debt': 0,
#   'amount': 800,
#   'price': 846},
#  {'status': 'ok',
#   'seniority': 17,
#   'home': 'rent',
#   'time': 60,
#   'age': 58,
#   'marital': 'widow',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 48,
#   'income': 131,
#   'assets': 0,
#   'debt': 0,
#   'amount': 1000,
#   'price': 1658},
#  {'status': 'default',
#   'seniority': 10,
#   'home': 'owner',
#   'time': 36,
#   'age': 46,
#   'marital': 'married',
#   'records': 'yes',
#   'job': 'freelance',
#   'expenses': 90,
#   'income': 200,
#   'assets': 3000,
#   'debt': 0,
#   'amount': 2000,
#   'price': 2985},
#  {'status': 'ok',
#   'seniority': 0,
#   'home': 'rent',
#   'time': 60,
#   'age': 24,
#   'marital': 'single',
#   'records': 'no',
#   'job': 'fixed',
#   'expenses': 63,
# ...

# %%
# Variables required for storing data on MongoDB
DB_NAME = "Credit_Scoring_Database"
COLLECTION_NAME = "credit_scoring_data_modified"
CONNECTION_URL = "mongodb+srv://learnermp_db_user:853gv5OEy7RlJ5iV@cluster0.0ariqsg.mongodb.net/?appName=Cluster0"

# %%
# Posting data at MongoDb

client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)
